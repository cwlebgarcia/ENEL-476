# %% [markdown]
# # Lab 2: Waves in Homogeneous Media
# All work and answers can be completed in the Jupyter notebook.
# [Shift]-[Enter] can be used to evaluate cells.
# Put two spaces at the end of a line in markdown cells for new lines.
# Math entry can be done between $\$$ signs e.g. $\eta = {a\over b}$ for in-line equations, or between $\$\$$ for separate-line equations e.g. $$\eta = {a\over b}$$

# %% [markdown]
# **Section:**

# %% [markdown]
# **Lab 02**

# %% [markdown]
# **Group Number:**

# %% [markdown]
# **Group 8**

# %% [markdown]
# **Student Names**

# %% [markdown]
# **Caleb Garcia** <br>
# **Khai Huynh** <br>
# **Diego Carrara** <br>
# **Junha Kim** <br>

# %% [markdown]
# **Student Numbers:**

# %% [markdown]
# **30214025** <br>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set(xlim=[-1,1], ylim=[-1,1], zlim=[-1,1],
       xlabel='x', ylabel='y', zlabel='z')

t = np.linspace(0, 100, 101)
x = np.cos(np.pi/50 * t)
y = np.sin(np.pi/50 * t)
z = np.sin(np.pi/10 * t)

# Create an empty line object
line, = ax.plot([], [], [], lw=2, color='k')

def update(frame):
    # Plot trajectory up to current frame
    line.set_data(x[:frame], y[:frame])
    line.set_3d_properties(z[:frame])
    return line,

ani = animation.FuncAnimation(fig, update, frames=len(t), interval=100)

plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## 3.1 Uniform Plane Wave Visualization

# %% [markdown]
# ### 1. Plot the electric and magnetic fields as a function of z at t= 0 in 3D.

# %%
from scipy.constants import epsilon_0, mu_0, c
import numpy as np
import matplotlib.pyplot as plt

E_0 = 1 # V/m
f = int(3e9) # GHz
angular_frequency = 2 * np.pi * f
t_max = 1e-9 # 1 ns
z_max = 30e-2 # m
conductivity = 0 # S / m
# Wave travelling in the z direction

alpha = 0
beta = angular_frequency  * np.sqrt(mu_0 * epsilon_0)
eta = np.sqrt(mu_0 / epsilon_0)

N = int(1e4)
t = 0
z = np.linspace(0, z_max, N)

E_x = E_0 * np.exp(-alpha * z) * np.cos(angular_frequency * t - beta * z)
H_y = E_x / np.abs(eta)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotting E_x and H_y as functions of z
ax.plot3D(0, H_y, z, label='H_y vs z', color='b')
ax.plot3D(E_x, 0, z, label='E_x vs z', color='r')

# Adding labels and title
ax.set_xlabel('E_x component')
ax.set_ylabel('H_y component')
ax.set_zlabel('z-axis')
ax.set_title('3D Plot of E_x and H_y as Functions of z')

# Show grid
ax.grid(True)
ax.legend()
plt.show()

# %% [markdown]
# ### 2. Plot the electric and magnetic fields as a function of time at z= 0 in 2D

# %%
import seaborn as sns

E_0 = 1 # V/m
f = int(3e9) # GHz
angular_frequency = 2 * np.pi * f
t_max = 1e-9 # 1 ns
z_max = 30e-2 # m
conductivity = 0 # S / m
# Wave travelling in the z direction

alpha = 0
beta = angular_frequency  * np.sqrt(mu_0 * epsilon_0)
eta = np.sqrt(mu_0 / epsilon_0)

N = int(1e4)
t = np.linspace(0, t_max, N)
z = 0

E_x = E_0 * np.exp(-alpha * z) * np.cos(angular_frequency * t - beta * z)
H_y = E_x / np.abs(eta)

ax = sns.lineplot(x=t, y=E_x)

# Adding labels and title
ax.set_xlabel('Time')
ax.set_ylabel('Magnitude of  E_X component (V/m)')
ax.set_title('Plot of E_x vs. t')

# Show grid
ax.grid(True)
plt.show()
plt.close()

ax = sns.lineplot(x=t, y=H_y)

# Adding labels and title
ax.set_xlabel('Time')
ax.set_ylabel('Magnitude of  H_y component (A/m)')
ax.set_title('Plot of H_y vs. t')

ax.grid(True)
plt.show()

# %% [markdown]
# ### 3. Plot the magnitude of the electric and magnetic field phasors in 3D.

# %%
E_0 = 1 # V/m
f = int(3e9) # GHz
angular_frequency = 2 * np.pi * f
t_max = 1e-9 # 1 ns
z_max = 30e-2 # m
conductivity = 0 # S / m
# Wave travelling in the z direction

alpha = 0
beta = angular_frequency  * np.sqrt(mu_0 * epsilon_0)
eta = np.sqrt(mu_0 / epsilon_0)
gamma = complex(alpha, beta)

N = int(1e4)
t = 0
z = np.linspace(0, z_max, N)

E_x = E_0 * np.exp(-1 * gamma * z)
H_y = E_x / np.abs(eta)
E_x = np.abs(E_x)
H_y = np.abs(H_y)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotting E_x and H_y as functions of z
ax.plot3D(z, H_y, 0, label='H_y vs z', color='b')
ax.plot3D(z, 0, E_x, label='E_x vs z', color='r')

# Adding labels and title
ax.set_xlabel('z-axis')
ax.set_ylabel('H_y component (A/m)')
ax.set_zlabel('E_x component (V/m)')
ax.set_title('3D Phasor Magnitude Plot of E_x and H_y as Functions of z')

# Show grid
ax.grid(True)
ax.legend()
plt.show()

# %% [markdown]
# ### 4. Generate an animation of the fields for 0 ≤t≤1 ns in 3D.

# %%
E_0 = 1 # V/m
f = int(3e9) # GHz
angular_frequency = 2 * np.pi * f
t_max = 1e-9 # 1 ns
z_max = 30e-2 # m
conductivity = 0 # S / m

alpha = 0
beta = angular_frequency  * np.sqrt(mu_0 * epsilon_0)
eta = np.sqrt(mu_0 / epsilon_0)

N = 100
t = np.linspace(0, t_max, N)
z = np.linspace(0, z_max, N)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlim(-1, 1)
ax.set_ylim(-1/eta, 1/eta)
ax.set_zlim(0, z_max)

ax.set_xlabel("E_x (V/m)")
ax.set_ylabel("H_y (A/m)")
ax.set_zlabel("z")

E_line, = ax.plot([], [], [], 'b', label="Electric field")
H_line, = ax.plot([], [], [], 'r', label="Magnetic field")

ax.legend()

def update(frame):

    time = t[frame]

    E_x = E_0 * np.exp(-alpha * z) * np.cos(angular_frequency * time - beta * z)
    H_y = E_x / np.abs(eta)

    E_line.set_data(E_x, np.zeros_like(z))
    E_line.set_3d_properties(z)

    H_line.set_data(np.zeros_like(z), H_y)
    H_line.set_3d_properties(z)

    return E_line, H_line

ani = animation.FuncAnimation(fig, update, frames=len(t), interval=50)

plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### 5. Wave traveling in +z-direction in free space at 3 GHz.

# %%
E_0 = 1 # V/m
f = int(3e9) # GHz
angular_frequency = 2 * np.pi * f
t_max = 1e-9 # 1 ns
z_max = 30e-2 # m
conductivity = 0 # S / m

alpha = 0
beta = angular_frequency  * np.sqrt(mu_0 * epsilon_0)
eta = np.sqrt(mu_0 / epsilon_0)

N = 100
t = np.linspace(0, t_max, N)
z = np.linspace(0, z_max, N)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlim(-1, 1)
ax.set_ylim(-1/eta, 1/eta)
ax.set_zlim(0, z_max)

ax.set_xlabel("E_x (V/m)")
ax.set_ylabel("H_y (A/m)")
ax.set_zlabel("z")

# Create full-wave line objects
E_line, = ax.plot([], [], [], 'b', label="Electric field")
H_line, = ax.plot([], [], [], 'r', label="Magnetic field")

ax.legend()

def update(frame):

    time = t[frame]

    E_x = E_0 * np.exp(-alpha * z) * np.cos(angular_frequency * time - beta * z)
    H_y = E_x / np.abs(eta)

    E_line.set_data(E_x, np.zeros_like(z))
    E_line.set_3d_properties(z)

    H_line.set_data(np.zeros_like(z), H_y)
    H_line.set_3d_properties(z)

    return E_line, H_line

ani = animation.FuncAnimation(fig, update, frames=len(t), interval=50)

plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### 6. Wave traveling in +z-direction in free space at 1.5 GHz

# %%
E_0 = 1 # V/m
f = int(15e8) # GHz
angular_frequency = 2 * np.pi * f
t_max = 1e-9 # 1 ns
z_max = 30e-2 # m
conductivity = 0 # S / m

alpha = 0
beta = angular_frequency  * np.sqrt(mu_0 * epsilon_0)
eta = np.sqrt(mu_0 / epsilon_0)

N = 100
t = np.linspace(0, t_max, N)
z = np.linspace(0, z_max, N)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlim(-1, 1)
ax.set_ylim(-1/eta, 1/eta)
ax.set_zlim(0, z_max)

ax.set_xlabel("E_x (V/m)")
ax.set_ylabel("H_y (A/m)")
ax.set_zlabel("z")

E_line, = ax.plot([], [], [], 'b', label="Electric field")
H_line, = ax.plot([], [], [], 'r', label="Magnetic field")

ax.legend()

def update(frame):

    time = t[frame]

    E_x = E_0 * np.exp(-alpha * z) * np.cos(angular_frequency * time - beta * z)
    H_y = E_x / np.abs(eta)

    E_line.set_data(E_x, np.zeros_like(z))
    E_line.set_3d_properties(z)

    H_line.set_data(np.zeros_like(z), H_y)
    H_line.set_3d_properties(z)

    return E_line, H_line

ani = animation.FuncAnimation(fig, update, frames=len(t), interval=50)

plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### 7. Wave traveling in +z-direction in a homogeneous medium with εr = 4,µr = 1, and σ= 0.1 S/m at 3 GHz.

# %%
E_0 = 1 # V/m
f = int(3e9) # GHz
angular_frequency = 2 * np.pi * f
t_max = 1e-9 # 1 ns
z_max = 30e-2 # m
relative_permittivity = 4
relative_permeability = 1
conductivity = 0.1 # S / m
# Wave travelling in the z direction

epsilon = epsilon_0 * relative_permittivity
mu = mu_0 * relative_permeability
alpha = angular_frequency * np.sqrt(mu * epsilon / 2 * 
                                    (np.sqrt(1 + np.power(conductivity / (angular_frequency * epsilon), 2) - 1))
                                    )
beta = angular_frequency * np.sqrt(mu * epsilon / 2 * 
                                    (np.sqrt(1 + np.power(conductivity / (angular_frequency * epsilon), 2) + 1))
                                    )
eta = np.sqrt(mu / epsilon) / np.power(1 + np.power(conductivity / (angular_frequency * epsilon), 2), 1/4)
theta_eta = 1/2 * np.atan(conductivity / (angular_frequency * epsilon))

N = 100
t = np.linspace(0, t_max, N)
z = z = np.linspace(0, z_max, N)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlim(-1, 1)
ax.set_ylim(-1/eta, 1/eta)
ax.set_zlim(0, z_max)

ax.set_xlabel("E_x (V/m)")
ax.set_ylabel("H_y (A/m)")
ax.set_zlabel("z")

E_line, = ax.plot([], [], [], 'b', label="Electric field")
H_line, = ax.plot([], [], [], 'r', label="Magnetic field")

ax.legend()

def update(frame):

    time = t[frame]

    E_x = E_0 * np.exp(-1 * alpha * z) * np.cos(angular_frequency * time - beta * z)
    H_y = E_0 * np.exp(-1 * alpha * z) * np.cos(angular_frequency * time - beta * z - theta_eta) / np.abs(eta)

    E_line.set_data(E_x, np.zeros_like(z))
    E_line.set_3d_properties(z)

    H_line.set_data(np.zeros_like(z), H_y)
    H_line.set_3d_properties(z)

    return E_line, H_line

ani = animation.FuncAnimation(fig, update, frames=len(t), interval=50)

plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### 8. Wave traveling in the -z-direction and E-field in the +x-direction in free space.

# %%
E_0 = 1 # V/m
f = int(3e9) # GHz
angular_frequency = 2 * np.pi * f
t_max = 1e-9 # 1 ns
z_max = 30e-2 # m
relative_permittivity = 1
relative_permeability = 1
conductivity = 0 # S / m
# Wave travelling in the -z direction

epsilon = epsilon_0 * relative_permittivity
mu = mu_0 * relative_permeability
alpha = angular_frequency * np.sqrt(mu * epsilon / 2 * 
                                    (np.sqrt(1 + np.power(conductivity / (angular_frequency * epsilon), 2) - 1))
                                    )
beta = angular_frequency * np.sqrt(mu * epsilon / 2 * 
                                    (np.sqrt(1 + np.power(conductivity / (angular_frequency * epsilon), 2) + 1))
                                    )
eta = np.sqrt(mu / epsilon) / np.power(1 + np.power(conductivity / (angular_frequency * epsilon), 2), 1/4)
theta_eta = 1/2 * np.atan(conductivity / (angular_frequency * epsilon))

N = 100
t = np.linspace(0, t_max, N)
z = np.linspace(-z_max, 0, N)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlim(-1, 1)
ax.set_ylim(-1/eta, 1/eta)
ax.set_zlim(-z_max, 0)

ax.set_xlabel("E_x (V/m)")
ax.set_ylabel("H_y (A/m)")
ax.set_zlabel("z")

E_line, = ax.plot([], [], [], 'b', label="Electric field")
H_line, = ax.plot([], [], [], 'r', label="Magnetic field")

ax.legend()

def update(frame):

    time = t[frame]

    E_x = E_0 * np.exp(-1 * alpha * z) * np.cos(angular_frequency * time + beta * z)
    H_y = E_0 * np.exp(-1 * alpha * z) * np.cos(angular_frequency * time + beta * z - theta_eta) / np.abs(eta)

    E_line.set_data(E_x, np.zeros_like(z))
    E_line.set_3d_properties(z)

    H_line.set_data(np.zeros_like(z), H_y)
    H_line.set_3d_properties(z)

    return E_line, H_line

ani = animation.FuncAnimation(fig, update, frames=len(t), interval=50)

plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### 9. The sum of a forward-traveling wave with magnitude 1 and phase 0, and a backward-traveling wave with magnitude 0.5 and phase π/4 where both are traveling in free space and both have E-field oriented in the +x- direction.

# %%
E_0 = 1 # V/m
phase_0 = 0 # rad
E_1 = 0.5 # V/m
phase_1 = np.pi / 4 # rad
f = int(3e9) # GHz
angular_frequency = 2 * np.pi * f
t_max = 1e-9 # 1 ns
z_max = 30e-2 # m
relative_permittivity = 1
relative_permeability = 1
conductivity = 0 # S / m

epsilon = epsilon_0 * relative_permittivity
mu = mu_0 * relative_permeability
alpha = angular_frequency * np.sqrt(mu * epsilon / 2 * 
                                    (np.sqrt(1 + np.power(conductivity / (angular_frequency * epsilon), 2) - 1))
                                    )
beta = angular_frequency * np.sqrt(mu * epsilon / 2 * 
                                    (np.sqrt(1 + np.power(conductivity / (angular_frequency * epsilon), 2) + 1))
                                    )
eta = np.sqrt(mu / epsilon) / np.power(1 + np.power(conductivity / (angular_frequency * epsilon), 2), 1/4)
theta_eta = 1/2 * np.atan(conductivity / (angular_frequency * epsilon))

N = 100
t = np.linspace(0, t_max, N)
z = t * -c

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlim(-1.2*(E_0+E_1), 1.2*(E_0+E_1))
ax.set_ylim(-1.2*(E_0+E_1)/eta, 1.2*(E_0+E_1)/eta)
ax.set_zlim(-z_max, 0)

ax.set_xlabel("E_x (V/m)")
ax.set_ylabel("H_y (A/m)")
ax.set_zlabel("z")

E_line, = ax.plot([], [], [], 'b', label="Electric field")
H_line, = ax.plot([], [], [], 'r', label="Magnetic field")

ax.legend()

def update(frame):

    time = t[frame]

    E_x0 = E_0 * np.exp(-alpha*z) * np.cos(angular_frequency*time - beta*z - phase_0)
    H_y0 = E_0 * np.exp(-alpha*z) * np.cos(angular_frequency*time - beta*z - theta_eta - phase_0) / np.abs(eta)

    E_x1 = E_1 * np.exp(-alpha*z) * np.cos(-angular_frequency*time - beta*z - phase_1)
    H_y1 = E_1 * np.exp(-alpha*z) * np.cos(-angular_frequency*time - beta*z - theta_eta - phase_1) / np.abs(eta)

    E = E_x0 + E_x1
    H = H_y0 + H_y1

    E_line.set_data(E, np.zeros_like(z))
    E_line.set_3d_properties(z)

    H_line.set_data(np.zeros_like(z), H)
    H_line.set_3d_properties(z)

    return E_line, H_line

ani = animation.FuncAnimation(fig, update, frames=len(t), interval=50)

plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### 10. What impact does increasing the permittivity have on the wavelength?

# %% [markdown]
# The velocity of the wave in the medium is determined by the equation
#
# $$v = \frac{1}{\sqrt{\mu\epsilon}}$$
#
# Which can be substituted into the equation
#
# $$v = f\lambda$$
#
# This can be rearranged into the equation
#
# $$\lambda = \frac{f}{\sqrt{\mu\epsilon}}$$
#
# Thus increasing the permittivity will have the effect of increasing the wavelength.

# %% [markdown]
# ### 11. How does decreasing the frequency impact the wavelength?

# %% [markdown]
# Decreasing the freqeuncy has the effect of increasing the wavelength. This can easily be seen in the equation
#
# $$c = f\lambda $$
#
# Where c is a constant. Thus so maintain equality, if frequency is increased wavelength must increase.

# %% [markdown]
# ### 12. What impact does increasing the permittivity have on the magnetic field strength?

# %% [markdown]
# Increasing the permittivity will have no effect on the magentic field strength as it is an electrical property. Changing the permeability will have an effect on the magnetic field strength, but the permittvity will not.

# %% [markdown]
# ### 13. How far does the wave travel before it undergoes 1 $Np$ of attenuation when εr = 4 and σ= 0.1 S/m.

# %% [markdown]
# To calculate how far the wave travels before undergoing $1 Np$ of attenutation, we can use the property that the units of $\alpha$ are $\frac{Np}{m}$.
#
# To find $\alpha$ we can use the general expression for a uniform plane wave:
#
# $$\alpha = \omega\sqrt{\frac{\mu\epsilon}{2}\left[\sqrt{1+\left[\frac{\sigma}{\omega\epsilon}\right]^2}-1\right]}$$
#
# Assuming $\mu _r = 1$ and $f = 3GHz$
#
# $$\alpha = 34.144 \frac{Np}{m}$$
#
# $$ \therefore \delta=\alpha^{-1}=0.2905m$$

# %% [markdown]
# ### 14. Describe the behavior of the wave resulting from the sum of forward and backward traveling waves over time?

# %% [markdown]
# The wave resulting from the sum of the forward and backward travelling waves should be a standing wave pattern in space, exhibiting stationary nodes and maximal amplitude antinodes.

# %% [markdown]
# ## 3.2 Half-Wavelength Dipole Antenna

# %%
E_0 = 1
I_0 = 1
frequency = int(3e9)
angular_frequency = frequency * 2 * np.pi
conductivity = 0
relative_permittivity = 1
relative_permeability = 1

epsilon = epsilon_0 * relative_permittivity
mu = mu_0 * relative_permeability

alpha = angular_frequency * np.sqrt((epsilon * mu / 2) * (np.sqrt((conductivity / (angular_frequency * epsilon) ** 2) + 1) - 1))
beta = angular_frequency * np.sqrt((epsilon * mu / 2) * (np.sqrt((conductivity / (angular_frequency * epsilon) ** 2) + 1) + 1))
eta = np.sqrt(mu / epsilon) * (1 / np.pow((1 + conductivity / (angular_frequency * epsilon) ** 2), 0.25))
theta_eta = np.arctan(conductivity / (angular_frequency * epsilon))/2

N = 100
t = np.linspace(0, 1e-9, N)

def E_field(X, Y, Z, t):
    r = np.sqrt(X ** 2 + Y ** 2 + Z ** 2)
    theta = np.arccos(np.clip(Z/r, -1, 1)) 
    phi = np.arctan2(Y, X)

    E = 1j * 60 * I_0 * (np.exp(-1j * beta * r) / r) * np.cos(0.5 * np.pi * np.cos(theta)) / np.sin(theta)

    E_x = np.real(np.cos(theta) * np.cos(phi) * E * np.exp(1j * angular_frequency * t))
    E_y = np.real(np.cos(theta) * np.sin(phi) * E * np.exp(1j * angular_frequency * t))
    E_z = np.real(-np.sin(theta) * E * np.exp(1j * angular_frequency * t))

    E_mag = np.sqrt(E_x ** 2 + E_y ** 2 + E_z ** 2)
    return E_mag

# %% [markdown]
# ### 15. Plot magnitude of the time-domain E-field (all components) in xy and xz planes in region near the antenna

# %%
x = np.linspace(0.1, 2, N)
y = np.linspace(-1, 1, N)
z = np.linspace(-1, 1, N)

X_xy, Y = np.meshgrid(x, y)   # xy plane, z=0
X_xz, Z = np.meshgrid(x, z)   # xz plane, y=0

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

im0 = axs[0].imshow(E_field(X_xy, Y, 0, t[0]), extent=[x.min(), x.max(), y.min(), y.max()], origin='lower', cmap='viridis', aspect='auto')
axs[0].set_title('E(xy)')
axs[0].set_xlabel('x (m)')
axs[0].set_ylabel('y (m)')
axs[0].grid(True)
fig.colorbar(im0, ax=axs[0], label='V(x,y)')

axs[0].set_xlim(x.min(), x.max())  
axs[0].set_ylim(y.min(), y.max())    

im1 = axs[1].imshow(E_field(X_xz, 0, Z, t[0]), extent=[x.min(), x.max(), z.min(), z.max()], origin='lower', cmap='viridis', aspect='auto')
axs[1].set_title('E(xz)')
axs[1].set_xlabel('x (m)')
axs[1].set_ylabel('z (m)')
axs[1].grid(True)
fig.colorbar(im1, ax=axs[1], label='V(x,z)')

axs[1].set_xlim(x.min(), x.max())
axs[1].set_ylim(z.min(), z.max())

plt.show()

# %% [markdown]
# ### 16. Using these plots and code similar to part 3.1 generate animations of the fields in the xy and xz planes.

# %%
X_xy, Y = np.meshgrid(x, y)   # xy plane, z=0
X_xz, Z = np.meshgrid(x, z)   # xz plane, y=0

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))

c1 = ax1.imshow(E_field(X_xy, Y, 0, t[0]), extent=[x.min(), x.max(), y.min(), y.max()],
                origin='lower', cmap='viridis', aspect='auto')
ax1.set_title('E(xy)')
ax1.set_xlabel('x (m)')
ax1.set_ylabel('y (m)')
fig.colorbar(c1, ax=ax1, label='|E|')

c2 = ax2.imshow(E_field(X_xz, 0, Z, t[0]), extent=[x.min(), x.max(), z.min(), z.max()],
                origin='lower', cmap='viridis', aspect='auto')
ax2.set_title('E(xz)')
ax2.set_xlabel('x (m)')
ax2.set_ylabel('z (m)')
fig.colorbar(c2, ax=ax2, label='|E|')

def update(frame):
    c1.set_data(E_field(X_xy, Y, 0, t[frame]))
    c2.set_data(E_field(X_xz, 0, Z, t[frame]))
    return c1, c2

ani = animation.FuncAnimation(fig, update, frames=len(t), interval=50, blit=True)
plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="1200" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### 17. Generate a plot further from the antenna (e.g. 2m ≤x ≤4m).

# %%
x = np.linspace(2, 4, N)
y = np.linspace(-1, 1, N)
z = np.linspace(-1, 1 ,N)

X_xy, Y = np.meshgrid(x, y)   # xy plane, z=0
X_xz, Z = np.meshgrid(x, z)   # xz plane, y=0

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

im0 = axs[0].imshow(E_field(X_xy, Y, 0, t[0]), extent=[x.min(), x.max(), y.min(), y.max()], origin='lower', cmap='viridis', aspect='auto')
axs[0].set_title('E(xy)')
axs[0].set_xlabel('x (m)')
axs[0].set_ylabel('y (m)')
axs[0].grid(True)
fig.colorbar(im0, ax=axs[0], label='V(x,y)')

axs[0].set_xlim(x.min(), x.max())  
axs[0].set_ylim(y.min(), y.max())    

im1 = axs[1].imshow(E_field(X_xz, 0, Z, t[0]), extent=[x.min(), x.max(), z.min(), z.max()], origin='lower', cmap='viridis', aspect='auto')
axs[1].set_title('E(xz)')
axs[1].set_xlabel('x (m)')
axs[1].set_ylabel('z (m)')
axs[1].grid(True)
fig.colorbar(im1, ax=axs[1], label='V(x,z)')

axs[1].set_xlim(x.min(), x.max())
axs[1].set_ylim(z.min(), z.max())

plt.show()

# %% [markdown]
# ### 18. Finally, generate an animation of the fields very far away from the dipole in the xy plane (e.g. 100m≤x≤102m,−1m≤y≤1m).

# %%
x = np.linspace(100,102,100)
y = np.linspace(-1,1,100)
z = np.linspace(-1,1,100)

X_xy, Y = np.meshgrid(x, y)   # xy plane, z=0

fig, ax1 = plt.subplots(figsize=(6,5))

c1 = ax1.imshow(E_field(X_xy, Y, 0, t[0]), extent=[x.min(),x.max(),y.min(),y.max()],
                origin='lower', cmap='viridis', aspect='auto')
ax1.set_title('E(xy)')
ax1.set_xlabel('x (m)')
ax1.set_ylabel('y (m)')
fig.colorbar(c1, ax=ax1, label='|E|')

def update(frame):
    c1.set_data(E_field(X_xy, Y, 0, t[frame]))
    return [c1]

ani = animation.FuncAnimation(fig, update, frames=len(t), interval=50, blit=False)
plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="600" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### 19. How does the E-field strength vary in the ϕ direction in the xy-plane?

# %% [markdown]
# ### 20. How does the E-field strength vary as the fields move farther from the antenna?

# %% [markdown]
# ### 21. Relative to the alignment of the dipole, in which direction is the E-field the weakest?

# %% [markdown]
# ### 22. Compare the behavior of the wave generated by the dipole antenna to a UPW at: 1) 0 ≤z≤2 m, 2) 2 m ≤z≤4 m, and 3) 100 m ≤z≤102 m.
